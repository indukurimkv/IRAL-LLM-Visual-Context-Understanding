# %%
import pandas as pd
import numpy as np

# %%
pd.read_json("./results copy/qwen_qwen3-vl-235b-a22b-instruct/classification_results.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/Code/roboflow-classification/venv/lib/python3.14/site-packages/pandas/io/json/_json.py:948, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     947 try:
# --> 948     self.handles = get_handle(
#     949         filepath_or_buffer,
#     950         "r",
#     951         encoding=self.encoding,
#     952         compression=self.compression,
#     953         storage_options=self.storage_options,
#     954         errors=self.encoding_errors,
#     955     )
#     956 except OSError as err:
#
# File ~/Documents/Code/roboflow-classification/venv/lib/python3.14/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     924 if ioargs.encoding and "b" not in ioargs.mode:
#     925     # Encoding
# ...
