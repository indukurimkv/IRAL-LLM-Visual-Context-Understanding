# %% [markdown]
# # Dense captioning generation
#
# 1. Get image url from roboflow
# 2. Query openrouter with image and get dense captinos
# 3. store url and dense captions in json format

# %%
import roboflow_client as rc
import dotenv
import os
import json
import time
import tqdm
import base64
from io import BytesIO
from PIL import Image
import requests
from tqdm.notebook import tqdm as tqdmnote
import openai as opi

for key in os.environ.keys():
    os.environ.pop(key)

dotenv.load_dotenv()
# Out:
# True

# %%
rf_client = rc.RoboflowAPIClient(os.getenv("ROBOFLOW_API_KEY"), os.getenv("ROBOFLOW_WORKSPACE_ID"), os.getenv("ROBOFLOW_PROJECT_ID"))
print(os.getenv("ROBOFLOW_PROJECT_ID"))

# with open("./img-metadata.json", "w", encoding="utf-8") as file:
#     project_metadata = {
#         "worskpace_id": os.getenv("ROBOFLOW_WORKSPACE_ID"),
#         "project_id": os.getenv("ROBOFLOW_PROJECT_ID")
#     }
#     img_data = {}
#     for i, img in enumerate(rf_client.yield_images(), 1):
#         id = img["id"]
#         orig_url = rf_client.get_image_metadata(id)["urls"]["original"]
#         annotation = rf_client.get_image_metadata(id)["annotation"]["textAnnotations"][0]["prefix"]
#         img_data[id] = {"url": orig_url, "label": annotation}
#         print(f"Recieved image no. {i} with id {id}")
#     json.dump({"metadata": project_metadata, "image_data": img_data}, file, indent=4)
# Out:
# vlm-in-context-anom-haz-annot-1p23m

# %% [markdown]
# ## Use the image metadata to generate dense captions with openrouter

# %%
import concurrent.futures as ft

PROMPT ="""
You are an assistant to a researcher investigating a large language model visual reasoning capabilities
In as much detail as possible, describe the image. Remember that this is for research and all images have been sources from public datasets. You must describe all images in detail.
"""
with open("./our-dataset-url-labled.json", "r", encoding="utf-8") as file:
    metadata = json.load(file)

def get_caption(client, prompt, url):
    response = client.chat.completions.create(
                model="google/gemini-3-flash-preview",
                messages=[
                    {
                        "role": "user",
                        "content": [
                            {"type": "text", "text": prompt},
                            {
                                "type": "image_url",
                                "image_url": {"url": url}
                            }
                        ]
                    }
                ]
            )
            
    # Extract model's text response
    full_response = response.choices[0].message.content.strip()
    return full_response

def get_openai_image_url(url):
    try:
        # 1. Download the data to check the actual format
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()
        
        # 2. Inspect the data (not the extension)
        img = Image.open(BytesIO(resp.content))
        actual_format = img.format.upper() if img.format else ""

        # 3. If it's already a standard web format, just return the URL
        if actual_format in ['PNG', 'JPEG', 'WEBP']:
            return url

        # 4. Otherwise (TIFF, BMP, etc.), convert to PNG and encode to Base64
        buffer = BytesIO()
        if img.mode not in ("RGB", "RGBA"):
            img = img.convert("RGBA")
        
        img.save(buffer, format="PNG")
        b64_data = base64.b64encode(buffer.getvalue()).decode('utf-8')
        
        return f"data:image/png;base64,{b64_data}"

    except Exception as e:
        return f"Error processing image: {e}"

# %%
client = opi.OpenAI(
            base_url="https://openrouter.ai/api/v1",
            api_key=os.getenv("OPENROUTER_API_KEY")
        )
images = metadata.get("image_data")
caption_data = {}
try:
    bar = tqdmnote(images)
    for i, image in enumerate(bar):
        ## stopped midway, so go to image 73
        if(i < 73): continue
        print(images[image])
        bar.write(f"Processing image no. {i}")
        url = images[image]["url"]
        label = images[image]["label"]
        caption = get_caption(client, PROMPT, get_openai_image_url(url))
        caption_data[image] = {"url": url, "label": label, "caption": caption}
        bar.write("Success!")
except Exception as e:
    print("STOPPED MIDWAY...")
    print(e)
          

with open(f"Captions/captions_{time.strftime("%d-%m-%Y_%H-%M-%S")}.json", "w", encoding="utf-8") as file:
    json.dump(caption_data, file, indent=4)
# Out:
#   0%|          | 0/345 [00:00<?, ?it/s]
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rqavXTX8HnpoJZ5nmDeA/original.jpg', 'label': '01'}
# Processing image no. 73
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/09uTB2tCaPXrqYdtQs7s/original.jpg', 'label': '11'}
# Processing image no. 74
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TlXdXLehjPTzLYW8oTO9/original.jpg', 'label': '10'}
# Processing image no. 75
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HE0tmEfLxQcMTINOYFKS/original.jpg', 'label': '00'}
# Processing image no. 76
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZR9bdkO2JB4Cgh29Mmv8/original.jpg', 'label': '11'}
# Processing image no. 77
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/fhjEgVwCgs85NPM7hwQo/original.jpg', 'label': '01'}
# Processing image no. 78
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uUVx31UGbbp6GyPW7xvb/original.jpg', 'label': '10'}
# Processing image no. 79
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IK1ayJ7AWBkixrJ6KrQ6/original.jpg', 'label': '00'}
# Processing image no. 80
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/MHOrlFgCFuqM3xNJxQyg/original.jpg', 'label': '00'}
# Processing image no. 81
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/WLjUKrEVjmc02ikLSrNc/original.jpg', 'label': '00'}
# Processing image no. 82
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/n9aopDOnEpAMny4M0QCP/original.jpg', 'label': '00'}
# Processing image no. 83
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/EwvC43YvKAMrT3r59xOz/original.jpg', 'label': '01'}
# Processing image no. 84
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/l73Y5C6KXGpS8Eovbx8k/original.jpg', 'label': '00'}
# Processing image no. 85
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/v5osZVCfF8OFYYPMZYV2/original.jpg', 'label': '10'}
# Processing image no. 86
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/lkE1c94J4wtLp7deNgaG/original.jpg', 'label': '00'}
# Processing image no. 87
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TbAcLG6gbg8HLWf11j9f/original.jpg', 'label': '00'}
# Processing image no. 88
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/y77x4ElFKt9pEvh9gS3l/original.jpg', 'label': '11'}
# Processing image no. 89
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Cue9dqAtX9cj8mmNzqGO/original.jpg', 'label': '00'}
# Processing image no. 90
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vklvAiEtVrRP2y1RA0OV/original.jpg', 'label': '00'}
# Processing image no. 91
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/eYHnxuirKkqjL9sfFNpR/original.jpg', 'label': '11'}
# Processing image no. 92
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ciNxOeDea2DujC2S0vpK/original.jpg', 'label': '11'}
# Processing image no. 93
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/qZqJr5Aktd15qFGvNYFZ/original.jpg', 'label': '00'}
# Processing image no. 94
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rpftoAyzwPGh5bq4FKLr/original.jpg', 'label': '11'}
# Processing image no. 95
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/WtzpuY5CKnxEsHfpswdI/original.jpg', 'label': '00'}
# Processing image no. 96
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/20LihFN82zYy2oit7Ak5/original.jpg', 'label': '00'}
# Processing image no. 97
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/0HNpYi9Tf7yMq7bZANXd/original.jpg', 'label': '10'}
# Processing image no. 98
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/iM8xFFBRXcvucDhUSmAp/original.jpg', 'label': '11'}
# Processing image no. 99
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TXe2yLkngomC26EmOXKu/original.jpg', 'label': '11'}
# Processing image no. 100
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9YoLDgdH4AECtmAGattp/original.jpg', 'label': '11'}
# Processing image no. 101
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rZNDsJKcXHdNepbSFnne/original.jpg', 'label': '11'}
# Processing image no. 102
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/LDJBQG9Y3SLNZ8dajBfh/original.jpg', 'label': '11'}
# Processing image no. 103
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9filbZHVswlMmp411PaN/original.jpg', 'label': '10'}
# Processing image no. 104
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rTqFsfLoe0244E2BIo4W/original.jpg', 'label': '00'}
# Processing image no. 105
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uHuwokwEHt6NpnMfrIe3/original.jpg', 'label': '11'}
# Processing image no. 106
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/0aoxPeVty4UWL2ng4pD3/original.jpg', 'label': '00'}
# Processing image no. 107
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/FNTApAiHYtqkAOI75x0i/original.jpg', 'label': '11'}
# Processing image no. 108
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9hVX9XZxZkouCZsWLYnH/original.jpg', 'label': '01'}
# Processing image no. 109
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/BGyFeXH9YgsDL7I06tfD/original.jpg', 'label': '01'}
# Processing image no. 110
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hrs5BL4xdlHfSDxgjVmX/original.jpg', 'label': '11'}
# Processing image no. 111
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vzvINnHpRYVDjfJeJdwe/original.jpg', 'label': '00'}
# Processing image no. 112
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/6DOQfDQa8NRg3GzTbKbF/original.jpg', 'label': '11'}
# Processing image no. 113
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ooyQyo8HW2KukvBP4Ah3/original.jpg', 'label': '11'}
# Processing image no. 114
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pJ8rjqzO2PJST0wsv4QH/original.jpg', 'label': '11'}
# Processing image no. 115
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/MnLDXrlXmLWIPY2DuhdA/original.jpg', 'label': '00'}
# Processing image no. 116
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pjOiOFK0TYb92r7AbMrf/original.jpg', 'label': '11'}
# Processing image no. 117
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/iSyAF82lzW2FCbOu8RvH/original.jpg', 'label': '00'}
# Processing image no. 118
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rTm6Ac96n5ujB0XoiIk9/original.jpg', 'label': '00'}
# Processing image no. 119
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ytgJbfA9AmgEkT762vyx/original.jpg', 'label': '00'}
# Processing image no. 120
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mehJJR7cahPB3329xXyf/original.jpg', 'label': '11'}
# Processing image no. 121
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/nh7NqAFVtkcCEnVU0vUM/original.jpg', 'label': '10'}
# Processing image no. 122
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/L0xIwSMbczejV1QntYyZ/original.jpg', 'label': '00'}
# Processing image no. 123
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/6YSzd4b4BLHER7ImMg3R/original.jpg', 'label': '00'}
# Processing image no. 124
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ooiefAt6uD3LVcQjFwJ5/original.jpg', 'label': '00'}
# Processing image no. 125
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9WyXQ5iNmdclkQce2qBm/original.jpg', 'label': '00'}
# Processing image no. 126
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Nc6p1Qq2lPxctQGiYY7b/original.jpg', 'label': '10'}
# Processing image no. 127
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/WYALaTDUwVyVHB2hNi9Z/original.jpg', 'label': '00'}
# Processing image no. 128
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cebkfpFP99GOIHu7iXvn/original.jpg', 'label': '00'}
# Processing image no. 129
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3XqCZ52TgPskprAtvCLt/original.jpg', 'label': '00'}
# Processing image no. 130
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/PyI3PxZwTsBPdm61Hrce/original.jpg', 'label': '00'}
# Processing image no. 131
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Orn1y88UQZV8s50nPzzs/original.jpg', 'label': '00'}
# Processing image no. 132
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3SN849jfrG65AixJXabt/original.jpg', 'label': '00'}
# Processing image no. 133
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/SxKRoiQqQrRu3M9r6SzX/original.jpg', 'label': '00'}
# Processing image no. 134
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VKmmWYhocWKiBLqI5Yfx/original.jpg', 'label': '00'}
# Processing image no. 135
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/63ujVDfpeLx3Vo2Snqyi/original.jpg', 'label': '00'}
# Processing image no. 136
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/eoep6KJBswyWZ4mDhJPC/original.jpg', 'label': '00'}
# Processing image no. 137
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3CMGd7sH9jCUTlPBTCWm/original.jpg', 'label': '00'}
# Processing image no. 138
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hjRZdrhcDm4z4jHF13uR/original.jpg', 'label': '00'}
# Processing image no. 139
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2qTjxrsgZHf2FetEsNAk/original.jpg', 'label': '00'}
# Processing image no. 140
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/OBA5IVJcTaJA9Xr2m2BM/original.jpg', 'label': '00'}
# Processing image no. 141
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/wNnuCqoW9pwwFNmSh70N/original.jpg', 'label': '11'}
# Processing image no. 142
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/xSFj8kCM2UsgCT2zYxMJ/original.jpg', 'label': '00'}
# Processing image no. 143
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/old9EiF7sG0pYEboWsMT/original.jpg', 'label': '00'}
# Processing image no. 144
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/EiMOfQL0luzhxAruR98W/original.jpg', 'label': '00'}
# Processing image no. 145
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/YedWswKNfFJbehY4AlAm/original.jpg', 'label': '11'}
# Processing image no. 146
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VZES0UWyTJ0waWNLvAZt/original.jpg', 'label': '00'}
# Processing image no. 147
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Qvo9n9Tkv27PbuRAlp9O/original.jpg', 'label': '00'}
# Processing image no. 148
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZbD4n0rHygWF7H6fWp5C/original.jpg', 'label': '00'}
# Processing image no. 149
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/KKmW52FtThrQo3zh623a/original.jpg', 'label': '00'}
# Processing image no. 150
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tX8OppUtPb58O8zmKSJA/original.jpg', 'label': '11'}
# Processing image no. 151
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/iThwR9wjV6q2PmbjlepK/original.jpg', 'label': '10'}
# Processing image no. 152
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VYaw5SZKYp7lK8JcXhEt/original.jpg', 'label': '10'}
# Processing image no. 153
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/S4lCLHvWd5H0PXe4RyML/original.jpg', 'label': '00'}
# Processing image no. 154
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/FizfoY8Q2pby7EG3gI50/original.jpg', 'label': '11'}
# Processing image no. 155
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GChXdJOEyoRQCvWvE4ea/original.jpg', 'label': '00'}
# Processing image no. 156
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IlAv1uKfgHPtMpJAWGuR/original.jpg', 'label': '00'}
# Processing image no. 157
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3pQqGFtqYBFtQ58NtbK6/original.jpg', 'label': '01'}
# Processing image no. 158
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/dJRLZCLONKVOcnUuOlkJ/original.jpg', 'label': '00'}
# Processing image no. 159
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/bkw692t0EQQ1PZrjhMAw/original.jpg', 'label': '00'}
# Processing image no. 160
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/T70Iga29GHO9SvddwCiR/original.jpg', 'label': '00'}
# Processing image no. 161
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/s6Yp8LJPunIRpjKqpETs/original.jpg', 'label': '10'}
# Processing image no. 162
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tS99SMLM7Zx96aHdkupP/original.jpg', 'label': '00'}
# Processing image no. 163
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/l93Co5HvInAUvAXHJBJV/original.jpg', 'label': '11'}
# Processing image no. 164
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Z3xISRYmkTUMgQ3xYLxA/original.jpg', 'label': '11'}
# Processing image no. 165
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/WQj9kEKXbVlJ4smQfvrc/original.jpg', 'label': '00'}
# Processing image no. 166
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/YCO54pnWOHOOCkSIwA61/original.jpg', 'label': '00'}
# Processing image no. 167
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/C21uOZKB4iBLCqZVlGSP/original.jpg', 'label': '11'}
# Processing image no. 168
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/yB1psj1DJyRKpJCSZ36e/original.jpg', 'label': '00'}
# Processing image no. 169
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/sZ127Rsd2kLIq3o8fKfZ/original.jpg', 'label': '00'}
# Processing image no. 170
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uu1myowDRZ6dlgBZjR2t/original.jpg', 'label': '00'}
# Processing image no. 171
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/lPasvsEniClJ8ifig6bz/original.jpg', 'label': '00'}
# Processing image no. 172
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9zhtChk7GKp9eWgAk4WK/original.jpg', 'label': '00'}
# Processing image no. 173
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/bHsf0Pv3TUE25dAlFboO/original.jpg', 'label': '01'}
# Processing image no. 174
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/CydIGrXZucwwy93zc9c4/original.jpg', 'label': '00'}
# Processing image no. 175
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/atDRRwa8UVj8khlXIp1C/original.jpg', 'label': '11'}
# Processing image no. 176
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/StxY6rDBpjBhV01o3Ned/original.jpg', 'label': '00'}
# Processing image no. 177
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GNaBgmXXd9WJvLvxRVcT/original.jpg', 'label': '11'}
# Processing image no. 178
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2BZP8alpOgC2hwpevsu1/original.jpg', 'label': '00'}
# Processing image no. 179
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5QK5SaeB0rwVEodQLw5E/original.jpg', 'label': '10'}
# Processing image no. 180
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/AZwIr81z9wNi6I2oLbL9/original.jpg', 'label': '00'}
# Processing image no. 181
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ykk6IDKkeq17zoHOtgra/original.jpg', 'label': '00'}
# Processing image no. 182
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/dEOd1xxHzio8YpgjdqcF/original.jpg', 'label': '01'}
# Processing image no. 183
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/afIi4tLaryNMloPtpQUh/original.jpg', 'label': '00'}
# Processing image no. 184
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/NAM3QlgXB9M3UWnOBrwP/original.jpg', 'label': '10'}
# Processing image no. 185
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/seByJVf3UEJeU1EE4EC3/original.jpg', 'label': '11'}
# Processing image no. 186
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/DCD8R7UgD4b9OMT8jE7Y/original.jpg', 'label': '10'}
# Processing image no. 187
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/qYVbYXyyJ95bFR6wkJJ1/original.jpg', 'label': '10'}
# Processing image no. 188
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/toGzcjiOVtby1ft3LJH4/original.jpg', 'label': '10'}
# Processing image no. 189
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vtIvEFGcVsPXbopOLliv/original.jpg', 'label': '10'}
# Processing image no. 190
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/egeUWLskAibc8ZNaDLfF/original.jpg', 'label': '10'}
# Processing image no. 191
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9bRJoeFOVbSd6vCWxDwv/original.jpg', 'label': '10'}
# Processing image no. 192
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tCh8XCZwac6JUZm8CVeL/original.jpg', 'label': '10'}
# Processing image no. 193
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/fIIVpPawY7cLg86ERzgU/original.jpg', 'label': '10'}
# Processing image no. 194
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ogiy6j9Hi2k7E3NniOIz/original.jpg', 'label': '10'}
# Processing image no. 195
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/A3ZCRfOwfkRU3C5daHUR/original.jpg', 'label': '00'}
# Processing image no. 196
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HrWjsGe2Eqn2W9BfkG7v/original.jpg', 'label': '00'}
# Processing image no. 197
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/55P2pUmHoTtc7GOEcKJ6/original.jpg', 'label': '11'}
# Processing image no. 198
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Y9APqEoOSz1FOJzdV4D9/original.jpg', 'label': '00'}
# Processing image no. 199
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/v8X8jANjF5uicAwn2pUf/original.jpg', 'label': '01'}
# Processing image no. 200
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/EVrWC6z6dDhv846U619V/original.jpg', 'label': '00'}
# Processing image no. 201
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/P0NPJ3C5EDi3TL5bLTT1/original.jpg', 'label': '00'}
# Processing image no. 202
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/33E7MvVKdB5BLzdLBlb9/original.jpg', 'label': '10'}
# Processing image no. 203
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/KIUJCI4PsoaPGhD09ugu/original.jpg', 'label': '10'}
# Processing image no. 204
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9ggjVEQobEVbI0SyXfD0/original.jpg', 'label': '11'}
# Processing image no. 205
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Qlz5YXZ4TYjusUYm1Klx/original.jpg', 'label': '11'}
# Processing image no. 206
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3Hx6SkVTmJWyIVLcDTZ0/original.jpg', 'label': '00'}
# Processing image no. 207
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/l6ycWLKfwQeiegSgO3dU/original.jpg', 'label': '00'}
# Processing image no. 208
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/bmkVXLPkDIEvEgNoMF04/original.jpg', 'label': '01'}
# Processing image no. 209
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/RfPavEoKk8bgHlaXfbdr/original.jpg', 'label': '00'}
# Processing image no. 210
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/KIyW1JuSmtLhRlAXoWw9/original.jpg', 'label': '00'}
# Processing image no. 211
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/qMv4fa5RED4S1vIXRJnQ/original.jpg', 'label': '11'}
# Processing image no. 212
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mLfYNWiynXFbKnxS1EXM/original.jpg', 'label': '10'}
# Processing image no. 213
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/oxCLjo190k7iA9bRnveO/original.jpg', 'label': '11'}
# Processing image no. 214
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Phn18Q7klr0L3ZgHNSIN/original.jpg', 'label': '00'}
# Processing image no. 215
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mE2dAclj6cJYwaIn5ZgD/original.jpg', 'label': '00'}
# Processing image no. 216
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/MV3yycxsKiYhRUVci0Vf/original.jpg', 'label': '10'}
# Processing image no. 217
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3zjlKMeJddLvzEX7qyNH/original.jpg', 'label': '00'}
# Processing image no. 218
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2tFCf1Fp97arLjA4OGM7/original.jpg', 'label': '01'}
# Processing image no. 219
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/lImfvzGRQNplpB3oeRxB/original.jpg', 'label': '00'}
# Processing image no. 220
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uIm3iFaRE9zbZpiWCi5Q/original.jpg', 'label': '01'}
# Processing image no. 221
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tKwvdp1aukkEwuZ5PFlH/original.jpg', 'label': '00'}
# Processing image no. 222
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uIYcZ4NdBdkoxqhSNpXU/original.jpg', 'label': '01'}
# Processing image no. 223
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ph9GoXxC4NmS3ReVbNjR/original.jpg', 'label': '11'}
# Processing image no. 224
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZxqAvf2zSZKm4SVxhlEy/original.jpg', 'label': '11'}
# Processing image no. 225
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/b0K11JjEQE7z8Rz8TGaZ/original.jpg', 'label': '11'}
# Processing image no. 226
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rb6SKeJY7DT2BekL13k3/original.jpg', 'label': '00'}
# Processing image no. 227
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/t5x2veqCS7NkqUCIPejF/original.jpg', 'label': '10'}
# Processing image no. 228
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vP1NVBGFvyLjW40Q5Ckp/original.jpg', 'label': '10'}
# Processing image no. 229
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/chLIqpKQui3kb0Gq0qM0/original.jpg', 'label': '10'}
# Processing image no. 230
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ggJAmPtPR40cWyngA3pO/original.jpg', 'label': '10'}
# Processing image no. 231
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/P3DMUm3LL6BfTa60gMiI/original.jpg', 'label': '11'}
# Processing image no. 232
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/a7GwrThSyqFmkvXBr5EN/original.jpg', 'label': '11'}
# Processing image no. 233
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mVYIDzBOybOx8jm7pyEJ/original.jpg', 'label': '11'}
# Processing image no. 234
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/42B7WTGNOniw2YRhAuFR/original.jpg', 'label': '11'}
# Processing image no. 235
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/k43XhJ7QRtrb4oDbk8nV/original.jpg', 'label': '11'}
# Processing image no. 236
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/aDQiyBXg4ByUwky0VFhe/original.jpg', 'label': '11'}
# Processing image no. 237
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/qw0JpHKlAaAYUHzKDfhR/original.jpg', 'label': '11'}
# Processing image no. 238
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/EM9IGt9s0QEziACu10om/original.jpg', 'label': '11'}
# Processing image no. 239
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/4pnYgdTAQ3wtYxOfLN8g/original.jpg', 'label': '10'}
# Processing image no. 240
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/c92qgUL90kMmsb8faoOB/original.jpg', 'label': '11'}
# Processing image no. 241
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pN0dKXKFApiW6iWJzmFE/original.jpg', 'label': '11'}
# Processing image no. 242
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/0julk89aylaEIJYVzzx7/original.jpg', 'label': '11'}
# Processing image no. 243
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/d6Ked27R8MkCbJi2lMll/original.jpg', 'label': '10'}
# Processing image no. 244
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/E0Tdl4frhNQo917w2p9d/original.jpg', 'label': '10'}
# Processing image no. 245
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9Tnbx2Rp09PNys4cAUGu/original.jpg', 'label': '10'}
# Processing image no. 246
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Uu5Nk2Vk1EBWKpxaORFr/original.jpg', 'label': '00'}
# Processing image no. 247
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZzEVF7I53AlLoGsuJHbu/original.jpg', 'label': '11'}
# Processing image no. 248
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/324TIyGjiXYEAzCBtrWf/original.jpg', 'label': '10'}
# Processing image no. 249
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/z27qTfnnAWBXqDnWHe19/original.jpg', 'label': '10'}
# Processing image no. 250
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cqUktD9UcsfUvmmEx49I/original.jpg', 'label': '00'}
# Processing image no. 251
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/NeszdBXuURPKIhZzZT6Y/original.jpg', 'label': '10'}
# Processing image no. 252
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JUGSgzfhYeuP9B0sil2T/original.jpg', 'label': '11'}
# Processing image no. 253
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8Rq6cxkhmavaRXzwR9OT/original.jpg', 'label': '11'}
# Processing image no. 254
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GMy2bUDvNckcXEuwaucE/original.jpg', 'label': '11'}
# Processing image no. 255
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IZprUanfjHoMi9Tn7n3K/original.jpg', 'label': '11'}
# Processing image no. 256
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/xzvgeEYC6LeZDkMneTpY/original.jpg', 'label': '00'}
# Processing image no. 257
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JQf5Gkz5qLj1DUNJ880c/original.jpg', 'label': '11'}
# Processing image no. 258
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/6LVKMWS2bSjYRA4sYzbt/original.jpg', 'label': '11'}
# Processing image no. 259
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/6WjVcBSzRFl6PylAjcUV/original.jpg', 'label': '10'}
# Processing image no. 260
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/gZi0cgYUTgRsw3J8HXrR/original.jpg', 'label': '00'}
# Processing image no. 261
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/opIQM9xzSbEqRzYNvS3J/original.jpg', 'label': '10'}
# Processing image no. 262
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/7uBCv79IwWJS5ygLXm2r/original.jpg', 'label': '11'}
# Processing image no. 263
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/fwdwoZOwiMWA8jmehBeE/original.jpg', 'label': '11'}
# Processing image no. 264
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/bYUrET8XhThRONDMwxse/original.jpg', 'label': '00'}
# Processing image no. 265
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/u0pGb9WmmwJfw3jmSp6T/original.jpg', 'label': '10'}
# Processing image no. 266
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9x9oAfCxp72xm203XB43/original.jpg', 'label': '10'}
# Processing image no. 267
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rER8lGe3jAJL4SN1kiWm/original.jpg', 'label': '10'}
# Processing image no. 268
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/o3cYfGRbOqtIwiIS7rna/original.jpg', 'label': '10'}
# Processing image no. 269
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GOeUPIAVPolSqlevTBs9/original.jpg', 'label': '11'}
# Processing image no. 270
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/89tKj7P90giVRNIqpDzC/original.jpg', 'label': '11'}
# Processing image no. 271
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5xI4f5vETarEuzjEINcU/original.jpg', 'label': '11'}
# Processing image no. 272
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/siG5lfKlOgDea8s44yKW/original.jpg', 'label': '11'}
# Processing image no. 273
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ilmvsLMC1SeA7FaVtJa9/original.jpg', 'label': '11'}
# Processing image no. 274
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/1pvcdVuP2iGgHQ3lxj2K/original.jpg', 'label': '10'}
# Processing image no. 275
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vFUzMHr4unyKg3g6emfa/original.jpg', 'label': '10'}
# Processing image no. 276
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/zb1UDkGiZG4mLwvIkqIZ/original.jpg', 'label': '10'}
# Processing image no. 277
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/y8r54DhBEWNWh8cpPh4w/original.jpg', 'label': '10'}
# Processing image no. 278
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/iNWHogUGsLgJdXjCoRWU/original.jpg', 'label': '10'}
# Processing image no. 279
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9woEKueGKZ7G9zzF312G/original.jpg', 'label': '10'}
# Processing image no. 280
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/b6BHVXDV0hEuJCbIS9Eh/original.jpg', 'label': '10'}
# Processing image no. 281
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/gNqfSso2ZjEjyiCv3DWg/original.jpg', 'label': '11'}
# Processing image no. 282
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IuRN5jbgsHiixszQwPla/original.jpg', 'label': '01'}
# Processing image no. 283
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2albgzJzBmCna7MhbdEc/original.jpg', 'label': '01'}
# Processing image no. 284
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hqhEMILVSd4pEY0eezCW/original.jpg', 'label': '10'}
# Processing image no. 285
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2qFk5oMcD3VBIQzuBWz7/original.jpg', 'label': '00'}
# Processing image no. 286
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/A53If0h6voLZajU24Bp3/original.jpg', 'label': '00'}
# Processing image no. 287
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/87Bxh178LfHvsZMDfnFg/original.jpg', 'label': '11'}
# Processing image no. 288
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vRw4u5Sf19CBeZ62eF1D/original.jpg', 'label': '01'}
# Processing image no. 289
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cocFiXZMfZ8aXkxdO9Pa/original.jpg', 'label': '11'}
# Processing image no. 290
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/gWnH3SdSXR4cowxCfxAn/original.jpg', 'label': '00'}
# Processing image no. 291
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/G83fbN9939J3psLY71u7/original.jpg', 'label': '00'}
# Processing image no. 292
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HxipNkEU0Pb96vCmKZts/original.jpg', 'label': '10'}
# Processing image no. 293
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/xLTAj5jFvgRM2J1VmzD0/original.jpg', 'label': '00'}
# Processing image no. 294
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uZZ8jaL9fbTRCk1HCKhj/original.jpg', 'label': '00'}
# Processing image no. 295
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/z71dUGFm3w6JHtoaEkmy/original.jpg', 'label': '11'}
# Processing image no. 296
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/nt1qS6Q5hKdZa7VAPnie/original.jpg', 'label': '00'}
# Processing image no. 297
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/E8i54Fvern7G6L1fiegl/original.jpg', 'label': '11'}
# Processing image no. 298
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pCcDNcxFxTaYuJmhcVFr/original.jpg', 'label': '11'}
# Processing image no. 299
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/EtxAU185VC3kjUpPrn4w/original.jpg', 'label': '00'}
# Processing image no. 300
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/OGJjHrW9Z1ZeB9nOawQM/original.jpg', 'label': '00'}
# Processing image no. 301
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JFrBZ9ztKwTqhaaiLea1/original.jpg', 'label': '11'}
# Processing image no. 302
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/LzNND9iXHNKDPyo5IXgu/original.jpg', 'label': '00'}
# Processing image no. 303
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/1FGKRFEW8aqlIZTn2nH6/original.jpg', 'label': '11'}
# Processing image no. 304
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ofb0emgW1SQNh2qylLp8/original.jpg', 'label': '11'}
# Processing image no. 305
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/AaD9gqgwYmxr4vTQWcY1/original.jpg', 'label': '11'}
# Processing image no. 306
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/t9CYLMvie9wUygUSnBDV/original.jpg', 'label': '01'}
# Processing image no. 307
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/jFoTSzzFodszIB5oGiUX/original.jpg', 'label': '01'}
# Processing image no. 308
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/UTEb7doSNVXmHzFCK3lV/original.jpg', 'label': '01'}
# Processing image no. 309
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vF9ujJ5soD4IrntdBq5x/original.jpg', 'label': '01'}
# Processing image no. 310
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/7eOd7LjdYUGt0auIUcPe/original.jpg', 'label': '01'}
# Processing image no. 311
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/NiVoCQVTz6dsWdt2C4BQ/original.jpg', 'label': '01'}
# Processing image no. 312
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HvwxSQS2dnKqy9I2Iz0w/original.jpg', 'label': '01'}
# Processing image no. 313
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hNLAWX510DLEQlLgrOjL/original.jpg', 'label': '01'}
# Processing image no. 314
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ur3FSsr7m6KqLRvRpwUf/original.jpg', 'label': '01'}
# Processing image no. 315
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2RpfCYhYh8fWHflZulcl/original.jpg', 'label': '01'}
# Processing image no. 316
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/D2OqCarGAjGBSlKpEjO1/original.jpg', 'label': '01'}
# Processing image no. 317
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JjSElgLP1tywYjK27imm/original.jpg', 'label': '01'}
# Processing image no. 318
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/4QR8XdvQXnoEOd3YsA3X/original.jpg', 'label': '01'}
# Processing image no. 319
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Dl4x3So1enj0e3r1XHsS/original.jpg', 'label': '11'}
# Processing image no. 320
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/YjzrUsBIXkDGPbzW99Oi/original.jpg', 'label': '11'}
# Processing image no. 321
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mpERFlis5pSPq9oIB0oo/original.jpg', 'label': '01'}
# Processing image no. 322
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JlRlxNxYxyQ9DMDRfj44/original.jpg', 'label': '11'}
# Processing image no. 323
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8ZO3MkJMWj42xz2kU3pM/original.jpg', 'label': '01'}
# Processing image no. 324
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/taKwuaCqcca10ONYfToe/original.jpg', 'label': '01'}
# Processing image no. 325
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/m3Eq5G8S1DwgOHjgFGtQ/original.jpg', 'label': '01'}
# Processing image no. 326
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/SziEwSpH83smauPnwt6v/original.jpg', 'label': '01'}
# Processing image no. 327
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/18eTmTtxxkh1ZCmw7VJ2/original.jpg', 'label': '01'}
# Processing image no. 328
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Sf0zAaErPyH7WYQeCGQc/original.jpg', 'label': '01'}
# Processing image no. 329
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/D9Qs2Rkofmo7upUfCmlF/original.jpg', 'label': '01'}
# Processing image no. 330
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cWTTryjjDHzMzWqLHFfn/original.jpg', 'label': '01'}
# Processing image no. 331
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/774prgnK2MGtbiGx1K02/original.jpg', 'label': '11'}
# Processing image no. 332
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/QtcMuYKQ5TS8kcWhTwnJ/original.jpg', 'label': '11'}
# Processing image no. 333
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hXb7U9OjhehC37MZdtpe/original.jpg', 'label': '11'}
# Processing image no. 334
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/aoncf7Zyp8ara0FXz6JW/original.jpg', 'label': '11'}
# Processing image no. 335
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/PvS1jZd3HRtlEJEk0q8L/original.jpg', 'label': '00'}
# Processing image no. 336
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TH2LbY2oqXNbNqb7ZOlu/original.jpg', 'label': '11'}
# Processing image no. 337
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ha2cUXTJj4eULDbNLW83/original.jpg', 'label': '11'}
# Processing image no. 338
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZITggF6gqcLQuPVxXjzG/original.jpg', 'label': '01'}
# Processing image no. 339
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/4GKr97yIVbjb6B0mBXPS/original.jpg', 'label': '01'}
# Processing image no. 340
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Vq6Hr9jsA3SDW9DfO26E/original.jpg', 'label': '01'}
# Processing image no. 341
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Fp5JOcFHScGp0fY2CtBh/original.jpg', 'label': '01'}
# Processing image no. 342
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cJJpkSCVmHqEAPAxaC5u/original.jpg', 'label': '01'}
# Processing image no. 343
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2CSMZacNkzzmfYvp9lRM/original.jpg', 'label': '01'}
# Processing image no. 344
# Success!
