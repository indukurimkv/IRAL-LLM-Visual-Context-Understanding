# %% [markdown]
# # Dense captioning generation
#
# 1. Get image url from roboflow
# 2. Query openrouter with image and get dense captinos
# 3. store url and dense captions in json format

# %%
import roboflow_client as rc
import dotenv
import os
import json
import time
import tqdm
import base64
from io import BytesIO
from PIL import Image
import requests
from tqdm.notebook import tqdm as tqdmnote
import openai as opi

for key in os.environ.keys():
    os.environ.pop(key)

dotenv.load_dotenv()
# Out:
# True

# %%
rf_client = rc.RoboflowAPIClient(os.getenv("ROBOFLOW_API_KEY"), os.getenv("ROBOFLOW_WORKSPACE_ID"), os.getenv("ROBOFLOW_PROJECT_ID"))
print(os.getenv("ROBOFLOW_PROJECT_ID"))

# Uncomment the following to generate metadata for a given dataset

with open("./img-metadata.json", "w", encoding="utf-8") as file:
    project_metadata = {
        "worskpace_id": os.getenv("ROBOFLOW_WORKSPACE_ID"),
        "project_id": os.getenv("ROBOFLOW_PROJECT_ID")
    }
    img_data = {}
    for i, img in enumerate(rf_client.yield_images(), 1):
        id = img["id"]
        orig_url = rf_client.get_image_metadata(id)["urls"]["original"]
        annotation = rf_client.get_image_metadata(id)["annotation"]["textAnnotations"][0]["prefix"]
        # fix for not getting hazard images
        if(annotation != "01"): continue
        img_data[id] = {"url": orig_url, "label": annotation}
        print(f"Recieved image no. {i} with id {id}")
    json.dump({"metadata": project_metadata, "image_data": img_data}, file, indent=4)
# Out:
# vlm-in-context-anom-haz-annot-1p23m
# Recieved image no. 29 with id bBXbS3LYNKgc4qZK1QLY
# Recieved image no. 37 with id EG7qBr1JeLqKDWg8Hizm
# Recieved image no. 74 with id rqavXTX8HnpoJZ5nmDeA
# Recieved image no. 79 with id fhjEgVwCgs85NPM7hwQo
# Recieved image no. 85 with id EwvC43YvKAMrT3r59xOz
# Recieved image no. 110 with id 9hVX9XZxZkouCZsWLYnH
# Recieved image no. 111 with id BGyFeXH9YgsDL7I06tfD
# Recieved image no. 159 with id 3pQqGFtqYBFtQ58NtbK6
# Recieved image no. 175 with id bHsf0Pv3TUE25dAlFboO
# Recieved image no. 184 with id dEOd1xxHzio8YpgjdqcF
# Recieved image no. 201 with id v8X8jANjF5uicAwn2pUf
# Recieved image no. 210 with id bmkVXLPkDIEvEgNoMF04
# Recieved image no. 220 with id 2tFCf1Fp97arLjA4OGM7
# Recieved image no. 222 with id uIm3iFaRE9zbZpiWCi5Q
# Recieved image no. 224 with id uIYcZ4NdBdkoxqhSNpXU
# Recieved image no. 284 with id IuRN5jbgsHiixszQwPla
# Recieved image no. 285 with id 2albgzJzBmCna7MhbdEc
# Recieved image no. 300 with id jlAzrTyq8JBXMnSLzf1l
# Recieved image no. 314 with id jlAzrTyq8JBXMnSLzf1l
# Recieved image no. 324 with id D2OqCarGAjGBSlKpEjO1
# Recieved image no. 325 with id 4QR8XdvQXnoEOd3YsA3X
# Recieved image no. 326 with id NiVoCQVTz6dsWdt2C4BQ
# Recieved image no. 327 with id vF9ujJ5soD4IrntdBq5x
# Recieved image no. 328 with id 7eOd7LjdYUGt0auIUcPe
# Recieved image no. 329 with id 2RpfCYhYh8fWHflZulcl
# Recieved image no. 330 with id t9CYLMvie9wUygUSnBDV
# Recieved image no. 331 with id jFoTSzzFodszIB5oGiUX
# Recieved image no. 332 with id ur3FSsr7m6KqLRvRpwUf
# Recieved image no. 333 with id UTEb7doSNVXmHzFCK3lV
# Recieved image no. 334 with id JjSElgLP1tywYjK27imm
# Recieved image no. 335 with id hNLAWX510DLEQlLgrOjL
# Recieved image no. 336 with id HvwxSQS2dnKqy9I2Iz0w
# Recieved image no. 337 with id Vq6Hr9jsA3SDW9DfO26E
# Recieved image no. 338 with id Fp5JOcFHScGp0fY2CtBh
# Recieved image no. 339 with id 4GKr97yIVbjb6B0mBXPS
# Recieved image no. 340 with id cJJpkSCVmHqEAPAxaC5u
# Recieved image no. 341 with id 2CSMZacNkzzmfYvp9lRM
# Recieved image no. 342 with id ZITggF6gqcLQuPVxXjzG
# Recieved image no. 352 with id mpERFlis5pSPq9oIB0oo
# Recieved image no. 353 with id Sf0zAaErPyH7WYQeCGQc
# Recieved image no. 354 with id D9Qs2Rkofmo7upUfCmlF
# Recieved image no. 355 with id SziEwSpH83smauPnwt6v
# Recieved image no. 356 with id 8ZO3MkJMWj42xz2kU3pM
# Recieved image no. 357 with id 18eTmTtxxkh1ZCmw7VJ2
# Recieved image no. 358 with id cWTTryjjDHzMzWqLHFfn
# Recieved image no. 359 with id taKwuaCqcca10ONYfToe
# Recieved image no. 360 with id m3Eq5G8S1DwgOHjgFGtQ
# Recieved image no. 361 with id EFxNryFxTwhgbaIBDkt5
# Recieved image no. 362 with id HoSop6MewtTjmHRccmy1
# Recieved image no. 363 with id W6Jgl8BB04i9clwqJYNH
# Recieved image no. 364 with id rNBL93QGQsyPIIvFwYoX
# Recieved image no. 365 with id owtqQbcIO70ei2Rnmnfr

# %% [markdown]
# ## Use the image metadata to generate dense captions with openrouter

# %%
import concurrent.futures as ft

PROMPT ="""
You are an assistant to a researcher investigating a large language model visual reasoning capabilities
In as much detail as possible, describe the image. Remember that this is for research and all images have been sources from public datasets. You must describe all images in detail.
"""
with open("./img-metadata.json", "r", encoding="utf-8") as file:
    metadata = json.load(file)

def get_caption(client, prompt, url):
    response = client.chat.completions.create(
                model="google/gemini-3-flash-preview",
                messages=[
                    {
                        "role": "user",
                        "content": [
                            {"type": "text", "text": prompt},
                            {
                                "type": "image_url",
                                "image_url": {"url": url}
                            }
                        ]
                    }
                ]
            )
            
    # Extract model's text response
    full_response = response.choices[0].message.content.strip()
    return full_response

def get_openai_image_url(url):
    try:
        # 1. Download the data to check the actual format
        resp = requests.get(url, timeout=10)
        resp.raise_for_status()
        
        # 2. Inspect the data (not the extension)
        img = Image.open(BytesIO(resp.content))
        actual_format = img.format.upper() if img.format else ""

        # 3. If it's already a standard web format, just return the URL
        if actual_format in ['PNG', 'JPEG', 'WEBP']:
            return url

        # 4. Otherwise (TIFF, BMP, etc.), convert to PNG and encode to Base64
        buffer = BytesIO()
        if img.mode not in ("RGB", "RGBA"):
            img = img.convert("RGBA")
        
        img.save(buffer, format="PNG")
        b64_data = base64.b64encode(buffer.getvalue()).decode('utf-8')
        
        return f"data:image/png;base64,{b64_data}"

    except Exception as e:
        return f"Error processing image: {e}"

# %%
client = opi.OpenAI(
            base_url="https://openrouter.ai/api/v1",
            api_key=os.getenv("OPENROUTER_API_KEY")
        )
images = metadata.get("image_data")
caption_data = {}
try:
    bar = tqdmnote(images)
    for i, image in enumerate(bar):
        print(images[image])
        bar.write(f"Processing image no. {i}")
        url = images[image]["url"]
        label = images[image]["label"]
        caption = get_caption(client, PROMPT, get_openai_image_url(url))
        caption_data[image] = {"url": url, "label": label, "caption": caption}
        bar.write("Success!")
except:
    print("STOPPED MIDWAY...")
          

with open(f"Captions/captions_{time.strftime("%d-%m-%Y_%H-%M-%S")}.json", "w", encoding="utf-8") as file:
    json.dump(caption_data, file, indent=4)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/kqPGqRb9aAj3cRzRCySq/original.jpg', 'label': '1'}
# Processing image no. 0
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vyzu4H89BV5IpdJOOjJG/original.jpg', 'label': '1'}
# Processing image no. 1
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5QfGY7vy3T0aN9e0ilBe/original.jpg', 'label': '0'}
# Processing image no. 2
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ac9Nb9CxhxdHAhMhRP6X/original.jpg', 'label': '0'}
# Processing image no. 3
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hsKtNmnjmSosOQzGdvxP/original.jpg', 'label': '1'}
# Processing image no. 4
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/CSvuldZIg1GYEmfvZipy/original.jpg', 'label': '1'}
# Processing image no. 5
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/n0BnmdMGLRlzu6rQDbfp/original.jpg', 'label': '1'}
# Processing image no. 6
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/DCAHhvVBtHMZ5uKulnU1/original.jpg', 'label': '0'}
# Processing image no. 7
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mmzTCdyo6piPr3wq26SJ/original.jpg', 'label': '0'}
# Processing image no. 8
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/mP4x83nrkBObA6fAmkHw/original.jpg', 'label': '0'}
# Processing image no. 9
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/u6ydcp481OxuavklehOt/original.jpg', 'label': '0'}
# Processing image no. 10
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9a27wUnixMOOp799YT8J/original.jpg', 'label': '0'}
# Processing image no. 11
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HLpCDx2kWBJakEnfhtxr/original.jpg', 'label': '1'}
# Processing image no. 12
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2iBOpSliBRqZCuwEY1aE/original.jpg', 'label': '1'}
# Processing image no. 13
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cmM3fyJod7eiXZc4Gaqm/original.jpg', 'label': '0'}
# Processing image no. 14
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2qm6hboP3Gsih8z0Ya0i/original.jpg', 'label': '0'}
# Processing image no. 15
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GC4HtvkrOK1yWxeowPCS/original.jpg', 'label': '0'}
# Processing image no. 16
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ct63eNhXRzQAgZyeAnNl/original.jpg', 'label': '1'}
# Processing image no. 17
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5h7WTbQtDRRPnMVvqTnA/original.jpg', 'label': '0'}
# Processing image no. 18
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/RPY51gq8vm6CK21j4Z0H/original.jpg', 'label': '1'}
# Processing image no. 19
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TcXSuufv6yGMRgaLMmCv/original.jpg', 'label': '1'}
# Processing image no. 20
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IMMFa6tIYvMEGndoTXxs/original.jpg', 'label': '0'}
# Processing image no. 21
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/2TLdcYJ8sTNVneA8OujH/original.jpg', 'label': '0'}
# Processing image no. 22
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/qAtihJlInMM3l9ivsWWn/original.jpg', 'label': '1'}
# Processing image no. 23
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/BnHtpsY6BMHQrOIyiijg/original.jpg', 'label': '0'}
# Processing image no. 24
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/xcKBYksqSj6yqeXKcmSD/original.jpg', 'label': '1'}
# Processing image no. 25
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/D6OrT1n3qtxermYFde9C/original.jpg', 'label': '1'}
# Processing image no. 26
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ne99Vnz00ZnhwsM6uU0G/original.jpg', 'label': '1'}
# Processing image no. 27
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vBriGBKam2WuJUBmRYvI/original.jpg', 'label': '0'}
# Processing image no. 28
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/M3ENGE8wcsL7qOoetygt/original.jpg', 'label': '1'}
# Processing image no. 29
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cpEwCcBrfkeb7SVPa7u4/original.jpg', 'label': '1'}
# Processing image no. 30
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ACrPCZK8A0ztQzaDIaeI/original.jpg', 'label': '0'}
# Processing image no. 31
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3UoxdNqTQuto0RDZAN63/original.jpg', 'label': '0'}
# Processing image no. 32
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/zK2dtvHS8h5mNOkzPA4I/original.jpg', 'label': '1'}
# Processing image no. 33
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/25U2C5ROXNBITczAZA1o/original.jpg', 'label': '0'}
# Processing image no. 34
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/a2yvg9AtOjnpJpwMWNqo/original.jpg', 'label': '1'}
# Processing image no. 35
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/lOAVNF7EEffGhwvuDPBm/original.jpg', 'label': '1'}
# Processing image no. 36
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5I5vgspulzitL2x4rAGc/original.jpg', 'label': '0'}
# Processing image no. 37
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9DOmLyqVw5im6Thx7tHf/original.jpg', 'label': '0'}
# Processing image no. 38
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/XzumOpA9jH59yskKQiuq/original.jpg', 'label': '0'}
# Processing image no. 39
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pDY2c6fQwlPKVZoOgnjo/original.jpg', 'label': '1'}
# Processing image no. 40
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/blviyzceLyGyOMe0JfoU/original.jpg', 'label': '1'}
# Processing image no. 41
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/fNJUoWiglVpSWK6LpEFI/original.jpg', 'label': '0'}
# Processing image no. 42
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JWlL34W265WmZTgXakal/original.jpg', 'label': '0'}
# Processing image no. 43
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/SQrTGFTQlBQjhLXfQMEF/original.jpg', 'label': '1'}
# Processing image no. 44
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/yNPyH1BMaGl2UBtZz4kt/original.jpg', 'label': '1'}
# Processing image no. 45
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tymsIG9YqX4dqlJVoQFS/original.jpg', 'label': '1'}
# Processing image no. 46
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HXHS24dM6ZLEFDaILb9H/original.jpg', 'label': '1'}
# Processing image no. 47
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/4IsNexx1yW8bxhn7CvJR/original.jpg', 'label': '0'}
# Processing image no. 48
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GXv6FH4NIE4NJlEjjL72/original.jpg', 'label': '0'}
# Processing image no. 49
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/DUdgK3LE1QBXKUnvythw/original.jpg', 'label': '1'}
# Processing image no. 50
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Wt0I1AJJAGtiNTuSpXbB/original.jpg', 'label': '0'}
# Processing image no. 51
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/t5hFOTA9UqkzrpooIGv4/original.jpg', 'label': '1'}
# Processing image no. 52
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/81Z6nZN6TFVSF6l8LcXT/original.jpg', 'label': '1'}
# Processing image no. 53
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/MRU3Co6PAhghzO4j6r7m/original.jpg', 'label': '0'}
# Processing image no. 54
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5gRRyU6peyqvhZi3ZwDb/original.jpg', 'label': '1'}
# Processing image no. 55
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/wStbXFTUHVkZIKjYdfSr/original.jpg', 'label': '0'}
# Processing image no. 56
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/SigWhYuQpJotI7CA0OSo/original.jpg', 'label': '1'}
# Processing image no. 57
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tfnH7nzf8LVmOV0hrYyh/original.jpg', 'label': '1'}
# Processing image no. 58
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/aFmKDS6yR28vRoEGBOh4/original.jpg', 'label': '1'}
# Processing image no. 59
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/YvUKOmFTyQxhdRzXnlM2/original.jpg', 'label': '0'}
# Processing image no. 60
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/x53IQ7bkSq4E7Jqc14Bp/original.jpg', 'label': '1'}
# Processing image no. 61
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hXldwEKIvMuFM3LO03f3/original.jpg', 'label': '0'}
# Processing image no. 62
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/C0CoMyXafunJW5Iacl4h/original.jpg', 'label': '0'}
# Processing image no. 63
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/iIKjwg4IczLTBnNrRUqO/original.jpg', 'label': '0'}
# Processing image no. 64
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/jXaeg5IkdxlNWVA1KrCv/original.jpg', 'label': '1'}
# Processing image no. 65
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tS36NGmjPzsKtSedYb2N/original.jpg', 'label': '0'}
# Processing image no. 66
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VgbFWMYkckXhuGdCzXeT/original.jpg', 'label': '0'}
# Processing image no. 67
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/6WNbQiKvTF5v5v615x3Z/original.jpg', 'label': '0'}
# Processing image no. 68
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/LBi9xuv7FrF1yHouXwH8/original.jpg', 'label': '1'}
# Processing image no. 69
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Cal5bStcq1sdAQHgm2qX/original.jpg', 'label': '0'}
# Processing image no. 70
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/H4xNlU2ODCSH9dv9cVn0/original.jpg', 'label': '1'}
# Processing image no. 71
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/U3VaaffVFnHEfZ1nterd/original.jpg', 'label': '0'}
# Processing image no. 72
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/RCEaw0rsQNTaDg6uiVuc/original.jpg', 'label': '1'}
# Processing image no. 73
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/jfxm4PZJKtJ7U4eQQoyx/original.jpg', 'label': '1'}
# Processing image no. 74
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hUwQishUbbhAF9Hkao6N/original.jpg', 'label': '0'}
# Processing image no. 75
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vxBhn3uF36kYtlDcbiHo/original.jpg', 'label': '1'}
# Processing image no. 76
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/NRUtkbiM9bvCDzP0XIeY/original.jpg', 'label': '0'}
# Processing image no. 77
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VC8PcvaxgAbyZnjlFiUH/original.jpg', 'label': '0'}
# Processing image no. 78
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cFlIjJKTu9IxYFznFHah/original.jpg', 'label': '0'}
# Processing image no. 79
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/dOxVICHQi9YxyQ0SrNj0/original.jpg', 'label': '0'}
# Processing image no. 80
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vbFSTb0CkU2EpxNLGWoA/original.jpg', 'label': '0'}
# Processing image no. 81
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/B8mNB2qtsuJtJdDgrQeg/original.jpg', 'label': '0'}
# Processing image no. 82
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/k9O9pqAa3OFBijITeE2u/original.jpg', 'label': '0'}
# Processing image no. 83
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/DWYv6bT4Beny7HHiZi5h/original.jpg', 'label': '0'}
# Processing image no. 84
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZqA7O3rw7HTg2CHZWdrU/original.jpg', 'label': '1'}
# Processing image no. 85
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/fDF1yE9mYSLpTzJlwn5O/original.jpg', 'label': '0'}
# Processing image no. 86
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/flR2Mh8b708foqk8jxRk/original.jpg', 'label': '1'}
# Processing image no. 87
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/FqNBP4fCX21c3AEaSmP7/original.jpg', 'label': '1'}
# Processing image no. 88
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HmviZBDRRSCOySchjXTl/original.jpg', 'label': '1'}
# Processing image no. 89
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/sLDa6jHpde043iCw52tf/original.jpg', 'label': '1'}
# Processing image no. 90
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ejG160M6Ty2JcoD3Ap1h/original.jpg', 'label': '1'}
# Processing image no. 91
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/87d2OUaMfA2LJ24o9Kxn/original.jpg', 'label': '1'}
# Processing image no. 92
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZHSQasTfjNqkqX94jiZH/original.jpg', 'label': '0'}
# Processing image no. 93
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZlNwIQQwsXrZsCKkTokQ/original.jpg', 'label': '1'}
# Processing image no. 94
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cn9OHC7QR1H14W5sdeYU/original.jpg', 'label': '0'}
# Processing image no. 95
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JkVwcoK7OvjLypMBmkPn/original.jpg', 'label': '0'}
# Processing image no. 96
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/KHssBcuy2UjKO9kaOECg/original.jpg', 'label': '1'}
# Processing image no. 97
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TPUiO3Jiexns7iqcoin9/original.jpg', 'label': '1'}
# Processing image no. 98
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/CSsn8jCfRVBACzFCt7nV/original.jpg', 'label': '1'}
# Processing image no. 99
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IxRAsJ8whl9RbhOpSPa3/original.jpg', 'label': '1'}
# Processing image no. 100
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8vM85uqHyCua9v0ty1zB/original.jpg', 'label': '1'}
# Processing image no. 101
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/t02k4mZH2BsVZ8ImAY9e/original.jpg', 'label': '0'}
# Processing image no. 102
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pS46I5sS9zrIKXh6v01O/original.jpg', 'label': '1'}
# Processing image no. 103
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ETMlsKp6seAcRZehH3c3/original.jpg', 'label': '0'}
# Processing image no. 104
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/UMpHIQ8JJ0gqWHLwjZVP/original.jpg', 'label': '1'}
# Processing image no. 105
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Nb5OieVa54VJ9LO8Jk8G/original.jpg', 'label': '1'}
# Processing image no. 106
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/p7rlq920ei9S8LgeyvUv/original.jpg', 'label': '1'}
# Processing image no. 107
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Bg9sHQ2yaV12CN9yGA3I/original.jpg', 'label': '0'}
# Processing image no. 108
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZcWj7MYfRLXQlJfCZZa9/original.jpg', 'label': '0'}
# Processing image no. 109
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3bV0qpEdAAYDXcLcxv3M/original.jpg', 'label': '0'}
# Processing image no. 110
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/KWPll1exzWucMHuZE1Ez/original.jpg', 'label': '1'}
# Processing image no. 111
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/yUT8HSWSuTZIKQbFvSFB/original.jpg', 'label': '0'}
# Processing image no. 112
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/RHKdjYqY8CQQiJp3JPGe/original.jpg', 'label': '0'}
# Processing image no. 113
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cfOpoMru48Evi0tcfBOF/original.jpg', 'label': '0'}
# Processing image no. 114
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/G8AeMjkeg6U9EJCiVnIn/original.jpg', 'label': '1'}
# Processing image no. 115
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/r7qnqgjpbz6gHndecvoB/original.jpg', 'label': '0'}
# Processing image no. 116
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/7F8l50ygsJYnhsvxZMEf/original.jpg', 'label': '0'}
# Processing image no. 117
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8O0C3TV1E6ypXnOUHfuj/original.jpg', 'label': '1'}
# Processing image no. 118
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/DKE8sZY6GXcx9F2UUZki/original.jpg', 'label': '1'}
# Processing image no. 119
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/xgfwwegOOB4wOlOEFgAe/original.jpg', 'label': '0'}
# Processing image no. 120
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uvUFCKEmAUHpysagCwDl/original.jpg', 'label': '1'}
# Processing image no. 121
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/G4ZOv3T6BoRZuDU9AM3H/original.jpg', 'label': '1'}
# Processing image no. 122
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/LaY6L22KrvN1VtUFXGZh/original.jpg', 'label': '0'}
# Processing image no. 123
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/XDX4ItefSJdgFpbv9h5v/original.jpg', 'label': '0'}
# Processing image no. 124
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/vUHBX6IZbyrkfR6jozdr/original.jpg', 'label': '1'}
# Processing image no. 125
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5xTh1Il0q1vm9jdHdTPN/original.jpg', 'label': '0'}
# Processing image no. 126
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8dvAj4JIP1N6s47dv6du/original.jpg', 'label': '1'}
# Processing image no. 127
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/RsIjhzkPvZfH5ZQokAQO/original.jpg', 'label': '1'}
# Processing image no. 128
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/cRtGwVhw3w0oHvFqfc6A/original.jpg', 'label': '0'}
# Processing image no. 129
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hyk25SxOUOfMKBHzHnB6/original.jpg', 'label': '1'}
# Processing image no. 130
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/BCDiYMtkfN5agXUhQKnV/original.jpg', 'label': '0'}
# Processing image no. 131
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ky79mGu7bnxjHDOuUluE/original.jpg', 'label': '0'}
# Processing image no. 132
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/iN8jwvg2H3RA96wTP7FV/original.jpg', 'label': '1'}
# Processing image no. 133
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/BiD1At1swy0s5NFtXw4P/original.jpg', 'label': '1'}
# Processing image no. 134
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/FnJPhXZDU88mUhPFYAIa/original.jpg', 'label': '1'}
# Processing image no. 135
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/3Zg3IZTzjZbySJsuoWtT/original.jpg', 'label': '0'}
# Processing image no. 136
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/FUXiqVDhtZ0sNW1AVWdE/original.jpg', 'label': '0'}
# Processing image no. 137
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ww3DkvM9uKpa9NX41jlK/original.jpg', 'label': '1'}
# Processing image no. 138
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/dbHz28yzEQFBtkLtSvIR/original.jpg', 'label': '1'}
# Processing image no. 139
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VtbyOYQcRWsKIMNIFou1/original.jpg', 'label': '0'}
# Processing image no. 140
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/oukxSR4oCuxxRod8BaTJ/original.jpg', 'label': '0'}
# Processing image no. 141
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/OxdjJzvxcgbMGo3NLRCe/original.jpg', 'label': '1'}
# Processing image no. 142
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/0CfBQS6Uj65kg1AIXnWZ/original.jpg', 'label': '0'}
# Processing image no. 143
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/fndLE8411XQSszo28mf7/original.jpg', 'label': '0'}
# Processing image no. 144
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/JZfD6ZO6DOWRZliU7Ifz/original.jpg', 'label': '1'}
# Processing image no. 145
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Y3ZqxturiWh3JVQ4rvJG/original.jpg', 'label': '1'}
# Processing image no. 146
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/UMalD4slAPCaFFFw8Ayj/original.jpg', 'label': '1'}
# Processing image no. 147
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/XGA4hqHgKGH3dPM6fNkE/original.jpg', 'label': '0'}
# Processing image no. 148
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/jeelpgqbyYgKen90GiTu/original.jpg', 'label': '1'}
# Processing image no. 149
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/l0kI31oER2qCsi0bTaY0/original.jpg', 'label': '0'}
# Processing image no. 150
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Qd0u71U4SEnptN4CImaX/original.jpg', 'label': '0'}
# Processing image no. 151
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/pHaYkinHsTOOODI9aJf6/original.jpg', 'label': '0'}
# Processing image no. 152
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/GiKXrHpJ3jIQgS63dAti/original.jpg', 'label': '0'}
# Processing image no. 153
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/e4JTdRAFbTYKvJOjsIJy/original.jpg', 'label': '0'}
# Processing image no. 154
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ny6hG4rRike2YAROBsx3/original.jpg', 'label': '1'}
# Processing image no. 155
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/QGqXeV9uDXmdWGf6wx8O/original.jpg', 'label': '0'}
# Processing image no. 156
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/uruMO5G8FiZGx48yfYVA/original.jpg', 'label': '0'}
# Processing image no. 157
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Zquf32dFZIZUb93dujkg/original.jpg', 'label': '1'}
# Processing image no. 158
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/9o4ZDcoSaQPKMPVYLV04/original.jpg', 'label': '0'}
# Processing image no. 159
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/7FZKg58GrypIWMgc0SI7/original.jpg', 'label': '1'}
# Processing image no. 160
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/5FwRACx5OODmknvDcXSP/original.jpg', 'label': '1'}
# Processing image no. 161
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/7sDLX9aus5tD6nGa0k4O/original.jpg', 'label': '1'}
# Processing image no. 162
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/U0K2Pj2W9EKGBMGxB82x/original.jpg', 'label': '0'}
# Processing image no. 163
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/TTsrQGq74taFt4UDQZ5q/original.jpg', 'label': '1'}
# Processing image no. 164
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HkV5RSUel2NKo9EXy5s4/original.jpg', 'label': '1'}
# Processing image no. 165
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ieEj0nIK8sBlboIeMcip/original.jpg', 'label': '1'}
# Processing image no. 166
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/J35yjfAoJ4W9XDhlbws3/original.jpg', 'label': '0'}
# Processing image no. 167
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8zGdXFwyG9fuFdB16Quf/original.jpg', 'label': '0'}
# Processing image no. 168
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ZY0E03shJQwccV5aNxi9/original.jpg', 'label': '0'}
# Processing image no. 169
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hdtY7bspM5dVVk8oV0Qh/original.jpg', 'label': '0'}
# Processing image no. 170
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/ALjBG1ANkKYx1o5zN1d4/original.jpg', 'label': '0'}
# Processing image no. 171
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/KECrb6neC4HlgRBi2xpu/original.jpg', 'label': '1'}
# Processing image no. 172
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/bi4iTBwXG1eO9ZmC7guS/original.jpg', 'label': '1'}
# Processing image no. 173
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hrevyyKrCNsr89BoSfuM/original.jpg', 'label': '0'}
# Processing image no. 174
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/lH3e52IhPNxbGBFZFwKT/original.jpg', 'label': '1'}
# Processing image no. 175
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/w9gjZqkHP0U2CSqflTa7/original.jpg', 'label': '1'}
# Processing image no. 176
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/QRKdcCFKpZVNSj4FJ40N/original.jpg', 'label': '1'}
# Processing image no. 177
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/qQA1YYrD7zuT6EuPVTvY/original.jpg', 'label': '0'}
# Processing image no. 178
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/F28GtyWY2h9kay8mbmVT/original.jpg', 'label': '0'}
# Processing image no. 179
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/1Jw1ik4Ujt0cZQIkO8cv/original.jpg', 'label': '1'}
# Processing image no. 180
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/PegLZD9kRKY1j66ba3wq/original.jpg', 'label': '0'}
# Processing image no. 181
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/dZZEMjjqwBnf6Ui4Dru9/original.jpg', 'label': '1'}
# Processing image no. 182
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/p19NzXbKPN4uVEXfpEM3/original.jpg', 'label': '0'}
# Processing image no. 183
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/smQMTAOWLyVevL0w93hQ/original.jpg', 'label': '0'}
# Processing image no. 184
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/P2zUm6wOFOcER6Kn90Wp/original.jpg', 'label': '1'}
# Processing image no. 185
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/4CaVedkjv2f0V5Hnuv3u/original.jpg', 'label': '1'}
# Processing image no. 186
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IzKL5uuJ1vzDohfBryEZ/original.jpg', 'label': '1'}
# Processing image no. 187
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/LbeunI4KyLY6o23JTlDY/original.jpg', 'label': '0'}
# Processing image no. 188
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/tDDASDiDbKvvD5ameb28/original.jpg', 'label': '1'}
# Processing image no. 189
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/hA14xeHuZC0E7MD5ttQG/original.jpg', 'label': '0'}
# Processing image no. 190
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/7E01WsNmIF8NoyXfxv8t/original.jpg', 'label': '1'}
# Processing image no. 191
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/q6cA2r1Z41jVf062dNjl/original.jpg', 'label': '0'}
# Processing image no. 192
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8IOxS7tPAMSZb6CtlcNy/original.jpg', 'label': '0'}
# Processing image no. 193
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/6ddnHHKOjY7TeNjKM8oE/original.jpg', 'label': '1'}
# Processing image no. 194
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/8NxJaxRrOYgsoRsRUegq/original.jpg', 'label': '1'}
# Processing image no. 195
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/b7qbXudcinZ4rMYELZwf/original.jpg', 'label': '0'}
# Processing image no. 196
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/UCGLQ25wI0lbvf8Ohk5H/original.jpg', 'label': '1'}
# Processing image no. 197
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/IM9MsFGGYc0i36zs69RT/original.jpg', 'label': '1'}
# Processing image no. 198
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/Ge2oBOoMxLgBdRguemV9/original.jpg', 'label': '0'}
# Processing image no. 199
# Success!

# %%
## Temporary code to fix our dataset captions(short of dangerous images)
client = opi.OpenAI(
            base_url="https://openrouter.ai/api/v1",
            api_key=os.getenv("OPENROUTER_API_KEY")
        )
images = metadata.get("image_data")
with open("./our-dataset-captions.json", "r", encoding="utf-8") as file:
    prev_data = json.load(file)
try:
    bar = tqdmnote(images)
    for i, image in enumerate(bar):
        if image in prev_data: continue
        print(images[image])
        bar.write(f"Processing image no. {i}")
        url = images[image]["url"]
        label = images[image]["label"]
        caption = get_caption(client, PROMPT, get_openai_image_url(url))
        prev_data[image] = {"url": url, "label": label, "caption": caption}
        bar.write("Success!")
except:
    print("STOPPED MIDWAY...")
          

with open(f"Captions/captions_{time.strftime("%d-%m-%Y_%H-%M-%S")}.json", "w", encoding="utf-8") as file:
    json.dump(prev_data, file, indent=4)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/jlAzrTyq8JBXMnSLzf1l/original.jpg', 'label': '01'}
# Processing image no. 17
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/EFxNryFxTwhgbaIBDkt5/original.jpg', 'label': '01'}
# Processing image no. 46
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/HoSop6MewtTjmHRccmy1/original.jpg', 'label': '01'}
# Processing image no. 47
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/W6Jgl8BB04i9clwqJYNH/original.jpg', 'label': '01'}
# Processing image no. 48
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/rNBL93QGQsyPIIvFwYoX/original.jpg', 'label': '01'}
# Processing image no. 49
# Success!
# {'url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/owtqQbcIO70ei2Rnmnfr/original.jpg', 'label': '01'}
# Processing image no. 50
# Success!
