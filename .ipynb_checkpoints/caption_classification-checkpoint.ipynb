# %%
from openrouter_client import *
from roboflow_client import *

import dotenv
import os
import json
import time
import tqdm
import base64
from io import BytesIO
from PIL import Image
import requests
from tqdm.notebook import tqdm as tqdmnote
import openai as opi

for key in os.environ.keys():
    os.environ.pop(key)

dotenv.load_dotenv()
# Out:
# True

# %%
rf_client = RoboflowAPIClient(os.getenv("ROBOFLOW_API_KEY"), os.getenv("ROBOFLOW_WORKSPACE_ID"), os.getenv("ROBOFLOW_PROJECT_ID"))
or_client = OpenRouterClient(os.getenv("OPENROUTER_API_KEY"))
print(os.getenv("ROBOFLOW_PROJECT_ID"))
# Out:
# veri-dataset

# %%
# Load the dense caption
with open("./our-dataset-captions.json", "r", encoding="utf-8") as file:
    caption_data = json.load(file)

# %%
# Get the annotations from the captions instead of images

# For each model
# For each image
# For a prompt set, get model output for each and daisy chain

# Can parallelize per model

"""
PROMPT: You are inspecting an environment for anomalies and hazards to help first responders. Use the following definitions. Assume the description is from the point of view of a person physically present in the scene. Hazard: A scene is hazardous if normal interaction would likely cause immediate physical harm, and the danger is unavoidable or easy to miss. Anomaly: A scene is anomalous if any visible element clearly violates normal expectations for this environment (location, arrangement, state, or use). Safe: Safe scenes include normal, expected human activities in the specifically given appropriate environment, provided no immediate physical hazard is present. Before predicting the code, internally reason through these steps. (1) Identify any real physically present element that could cause immediate physical harm without speculating. (2) If harm is likely and real, determine whether it is unavoidable or easy to miss. (3) Independently determine whether any element violates normal expectations for this environment. (4) Decide whether anomaly and hazard are present independently. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary.
"""

def query_model(model: str, img_data, prompt_set, output_dat):
    if len(prompt_set) == 0:
        print("No prompt!")
        return ""

    or_client.prompt = ""
    model_prediction = ""
    model_response = ""
    caption = img_data["caption"]
    img_id = img_data["id"]
    img_url = img_data["url"]
    img_label = img_data["label"]

    history = ""
    for prompt in prompt_set:
        history += prompt + "\n" + caption if not history else "\n" + prompt
        model_prediction, model_response = or_client.classify_caption(history)
        history += "\n" + model_response
    
    output_dat.append({
        "image_id": img_id,
        "image_url": img_url,
        "ground_truth": img_label,
        "model_prediction": model_prediction,
        "model_response": model_response,
        "timestamp": time.strftime("%Y-%m-%dT%H:%M:%S"),
        "match": model_prediction == img_label
    })

# %%
outputs = []
prompt_set = [
        "Think about the description and what potential sources of hazards and anomalies are and how hazard might differ from anomaly",
        "Use your thoughts to identify any hazards in the scene. A hazard is anything that can cause harm to people or property and it is unavoidable to easy to miss in the description.",
        "Seperately, think about anomalies in the description. Anomaly is anything that defies common sense and sources might include objects that are not inline with the context of the image.",
        "Decide if the description is safe, anomalous, hazardous, or both using your thoughts. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary."
]
for i, image in enumerate(caption_data):
    data = caption_data[image]
    data["id"] = image
    query_model("google/gemini-3-flash-preview", data, [
        "Think about the description and what potential sources of hazards and anomalies are and how hazard might differ from anomaly",
        "Use your thoughts to identify any hazards in the scene. A hazard is anything that can cause harm to people or property and it is unavoidable to easy to miss in the description.",
        "Seperately, think about anomalies in the description. Anomaly is anything that defies common sense and sources might include objects that are not inline with the context of the image.",
        "Decide if the description is safe, anomalous, hazardous, or both using your thoughts. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary."
                                                       ], outputs)
    if (i >= 3): break

print(outputs)
# Out:
# Using image: r3Bbl9RVhSDU8ZVPf7uK with prompt: Think about the description and what potential sources of hazards and anomalies are and how hazard might differ from anomaly
# Using image: r3Bbl9RVhSDU8ZVPf7uK with prompt: Use your thoughts to identify any hazards in the scene. A hazard is anything that can cause harm to people or property and it is unavoidable to easy to miss in the description.
# Using image: r3Bbl9RVhSDU8ZVPf7uK with prompt: Seperately, think about anomalies in the description. Anomaly is anything that defies common sense and sources might include objects that are not inline with the context of the image.
# Using image: r3Bbl9RVhSDU8ZVPf7uK with prompt: Decide if the description is safe, anomalous, hazardous, or both using your thoughts. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary.
# Using image: VgUi4JygVBe9D9c9oA97 with prompt: Think about the description and what potential sources of hazards and anomalies are and how hazard might differ from anomaly
# Using image: VgUi4JygVBe9D9c9oA97 with prompt: Use your thoughts to identify any hazards in the scene. A hazard is anything that can cause harm to people or property and it is unavoidable to easy to miss in the description.
# Using image: VgUi4JygVBe9D9c9oA97 with prompt: Seperately, think about anomalies in the description. Anomaly is anything that defies common sense and sources might include objects that are not inline with the context of the image.
# Using image: VgUi4JygVBe9D9c9oA97 with prompt: Decide if the description is safe, anomalous, hazardous, or both using your thoughts. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary.
# Using image: 781rGblmCTHhWj3obtbF with prompt: Think about the description and what potential sources of hazards and anomalies are and how hazard might differ from anomaly
# Using image: 781rGblmCTHhWj3obtbF with prompt: Use your thoughts to identify any hazards in the scene. A hazard is anything that can cause harm to people or property and it is unavoidable to easy to miss in the description.
# Using image: 781rGblmCTHhWj3obtbF with prompt: Seperately, think about anomalies in the description. Anomaly is anything that defies common sense and sources might include objects that are not inline with the context of the image.
# Using image: 781rGblmCTHhWj3obtbF with prompt: Decide if the description is safe, anomalous, hazardous, or both using your thoughts. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary.
# Using image: SifG7P9TyvQP4dbMsL6C with prompt: Think about the description and what potential sources of hazards and anomalies are and how hazard might differ from anomaly
# Using image: SifG7P9TyvQP4dbMsL6C with prompt: Use your thoughts to identify any hazards in the scene. A hazard is anything that can cause harm to people or property and it is unavoidable to easy to miss in the description.
# Using image: SifG7P9TyvQP4dbMsL6C with prompt: Seperately, think about anomalies in the description. Anomaly is anything that defies common sense and sources might include objects that are not inline with the context of the image.
# Using image: SifG7P9TyvQP4dbMsL6C with prompt: Decide if the description is safe, anomalous, hazardous, or both using your thoughts. You MUST obey this strict output format: <a brief, explicit justification for the final decision>: <code> Where <code> is ONLY one of: 00 Safe 10 Anomalous 01 = Hazardous 11 = Anomalous Hazardous - No extra paragraphs, no bullet points, no additional commentary.
# [{'image_id': 'r3Bbl9RVhSDU8ZVPf7uK', 'image_url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/r3Bbl9RVhSDU8ZVPf7uK/original.jpg', 'ground_truth': '00', 'model_prediction': '00', 'model_response': 'Normal office/institutional hallway with standard fixtures, proper lighting, and conventional furnishings arranged appropriately with no physical hazards or unexpected elements: 00 Safe', 'timestamp': '2026-03-08T10:53:39', 'match': True}, {'image_id': 'VgUi4JygVBe9D9c9oA97', 'image_url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/VgUi4JygVBe9D9c9oA97/original.jpg', 'ground_truth': '00', 'model_prediction': '00', 'model_response': 'Standard dining room with proper lighting installation, conventional furniture arrangement, and normal decorative elements - no hazards or unexpected features present: 00 Safe', 'timestamp': '2026-03-08T10:53:54', 'match': True}, {'image_id': '781rGblmCTHhWj3obtbF', 'image_url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/781rGblmCTHhWj3obtbF/original.jpg', 'ground_truth': '00', 'model_prediction': '01', 'model_response': 'The exposed Edison bulbs on the industrial chandelier at head/eye level create a burn hazard, as vintage-style bulbs operate at high temperatures and their placement makes accidental contact likely during normal movement through the space: 01 Hazardous', 'timestamp': '2026-03-08T10:54:02', 'match': False}, {'image_id': 'SifG7P9TyvQP4dbMsL6C', 'image_url': 'https://source.roboflow.com/1xWq74G9WjZc9URmJ7tZ8ho2f1Z2/SifG7P9TyvQP4dbMsL6C/original.jpg', 'ground_truth': '00', 'model_prediction': '00', 'model_response': 'Normal urban intersection with standard traffic patterns, proper road markings, expected infrastructure and typical building/parking arrangements for a Chinese city environment - no hazards or anomalies present: 00 Safe', 'timestamp': '2026-03-08T10:54:13', 'match': True}]
